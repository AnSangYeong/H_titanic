# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 18,9
rcParams['font.family'] = 'AppleGothic' #malgun Gothic


from google.colab import files     #colab 돌릴때
uploaded = files.upload()          #colab 돌릴때
# Out:
#      <input type="file" id="files-6cd87b16-048f-4f11-b4df-02c6ab9557f0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6cd87b16-048f-4f11-b4df-02c6ab9557f0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving winequality-red.csv to winequality-red.csv
# Saving winequality-white.csv to winequality-white.csv

# %%
red = pd.read_csv("winequality-red.csv", sep=';')             # 구분자가 콤마, 가 아닌....  세미콜론;임
print(red.shape)
red.head()
# Out:
# (1599, 12)
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
import glob      # 묶어주는 라이브러리
import os        # 폴더를 컨트롤

# %%
all_files = glob.glob(os.path.join('wine*'))
all_files
# Out:
# ['winequality-red.csv', 'winequality-white.csv']

# %%
all_data = []     # 모든 데이터를 저장하기 위해 빈리스트를 만들어둠

i=0

for file in all_files:
    data = pd.read_csv(file, sep=';')
    data['type']=i
    all_data.append(data)
    i+=1         # 타입을 확인함.   레드는 0, 화이트는 1로 정의하여 와인 구분함.
    
wine = pd.concat(all_data, ignore_index=True)      # 데이터를 합침concat, concat은 axis가 기본값이   0임,  
                                                    #기존인데스를 가지고 와서 6천여개중 4900여개로 표시됨, 그래서 기존 인데스 무시처리

# %%
wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 6492                 24.0                  92.0  0.99114  3.27       0.50
# 6493                 57.0                 168.0  0.99490  3.15       0.46
# 6494                 30.0                 111.0  0.99254  2.99       0.46
# 6495                 20.0                 110.0  0.98869  3.34       0.38
# 6496                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality  type
# 0         9.4        5     0
# 1         9.8        5     0
# 2         9.8        5     0
# 3         9.8        6     0
# 4         9.4        5     0
# ...       ...      ...   ...
# 6492     11.2        6     1
# 6493      9.6        5     1
# 6494      9.4        6     1
# 6495     12.8        7     1
# 6496     11.8        6     1
#
# [6497 rows x 13 columns]

# %%
wine.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6497.000000       6497.000000  6497.000000     6497.000000
# mean        7.215307          0.339666     0.318633        5.443235
# std         1.296434          0.164636     0.145318        4.757804
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6497.000000          6497.000000           6497.000000  6497.000000
# mean      0.056034            30.525319            115.744574     0.994697
# std       0.035034            17.749400             56.521855     0.002999
# min       0.009000             1.000000              6.000000     0.987110
# 25%       0.038000            17.000000             77.000000     0.992340
# 50%       0.047000            29.000000            118.000000     0.994890
# 75%       0.065000            41.000000            156.000000     0.996990
# max       0.611000           289.000000            440.000000     1.038980
#
#                 pH    sulphates      alcohol      quality         type
# count  6497.000000  6497.000000  6497.000000  6497.000000  6497.000000
# mean      3.218501     0.531268    10.491801     5.818378     0.753886
# std       0.160787     0.148806     1.192712     0.873255     0.430779
# min       2.720000     0.220000     8.000000     3.000000     0.000000
# 25%       3.110000     0.430000     9.500000     5.000000     1.000000
# 50%       3.210000     0.510000    10.300000     6.000000     1.000000
# 75%       3.320000     0.600000    11.300000     6.000000     1.000000
# max       4.010000     2.000000    14.900000     9.000000     1.000000

# %% [markdown]
# > **우리의 목표: 와인성분데이터를 넣으면 와인의 품질을 예측하는 모형

# %%
sorted(wine.quality.unique())             # 목표 변수
# Out:
# [3, 4, 5, 6, 7, 8, 9]

# %%
wine.quality.value_counts()               # 값 별 카운트
# Out:
# 6    2836
# 5    2138
# 7    1079
# 4     216
# 8     193
# 3      30
# 9       5
# Name: quality, dtype: int64

# %%
wine[wine.quality ==9]                   # 특정 값을 지는 리스트를 보고 싶어
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 2373            9.1              0.27         0.45            10.6      0.035
# 2419            6.6              0.36         0.29             1.6      0.021
# 2426            7.4              0.24         0.36             2.0      0.031
# 2475            6.9              0.36         0.34             4.2      0.018
# 3204            7.1              0.26         0.49             2.2      0.032
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 2373                 28.0                 124.0  0.99700  3.20       0.46
# 2419                 24.0                  85.0  0.98965  3.41       0.61
# 2426                 27.0                 139.0  0.99055  3.28       0.48
# 2475                 57.0                 119.0  0.98980  3.28       0.36
# 3204                 31.0                 113.0  0.99030  3.37       0.42
#
#       alcohol  quality  type
# 2373     10.4        9     1
# 2419     12.4        9     1
# 2426     12.5        9     1
# 2475     12.7        9     1
# 3204     12.9        9     1

# %% [markdown]
# ### 탐색적분석  ------------------------
# - 레드와인인지 화이트와인인지에 따라 품질이 다를까?

# %%
wine.groupby('type').quality.describe()
# Out:
#        count      mean       std  min  25%  50%  75%  max
# type
# 0     1599.0  5.636023  0.807569  3.0  5.0  6.0  6.0  8.0
# 1     4898.0  5.877909  0.885639  3.0  5.0  6.0  6.0  9.0

# %%
red_quality = wine.loc[wine.type == 0, 'quality']

# %%
white_quality = wine.loc[wine.type==1, 'quality']

# %%
sns.distplot(red_quality, label='Red')
sns.distplot(white_quality, label="White")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# findfont: Font family ['AppleGothic'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# ### T검정
# - 와인종류에 따른 품질의 차이가 통계적으로 유의한지 확인하기 위함
# - p value < 0.05     그래야 유의미한 의미임 95%  ******

# %%
import statsmodels.api as sm
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
tstat, pvalue, df = sm.stats.ttest_ind(red_quality, white_quality)

# %%
print("T값은 %.5f, p-value는 %.8f"%(tstat, pvalue))
# Out:
# T값은 -9.68565, p-value는 0.00000000

# %% [markdown]
# ### 상관관계분석

# %%
wine.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000          0.219008     0.324436
# volatile acidity           0.219008          1.000000    -0.377981
# citric acid                0.324436         -0.377981     1.000000
# residual sugar            -0.111981         -0.196011     0.142451
# chlorides                  0.298195          0.377124     0.038998
# free sulfur dioxide       -0.282735         -0.352557     0.133126
# total sulfur dioxide      -0.329054         -0.414476     0.195242
# density                    0.458910          0.271296     0.096154
# pH                        -0.252700          0.261454    -0.329808
# sulphates                  0.299568          0.225984     0.056197
# alcohol                   -0.095452         -0.037640    -0.010493
# quality                   -0.076743         -0.265699     0.085532
# type                      -0.486740         -0.653036     0.187397
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity              -0.111981   0.298195            -0.282735
# volatile acidity           -0.196011   0.377124            -0.352557
# citric acid                 0.142451   0.038998             0.133126
# residual sugar              1.000000  -0.128940             0.402871
# chlorides                  -0.128940   1.000000            -0.195045
# free sulfur dioxide         0.402871  -0.195045             1.000000
# total sulfur dioxide        0.495482  -0.279630             0.720934
# density                     0.552517   0.362615             0.025717
# pH                         -0.267320   0.044708            -0.145854
# sulphates                  -0.185927   0.395593            -0.188457
# alcohol                    -0.359415  -0.256916            -0.179838
# quality                    -0.036980  -0.200666             0.055463
# type                        0.348821  -0.512678             0.471644
#
#                       total sulfur dioxide   density        pH  sulphates  \
# fixed acidity                    -0.329054  0.458910 -0.252700   0.299568
# volatile acidity                 -0.414476  0.271296  0.261454   0.225984
# citric acid                       0.195242  0.096154 -0.329808   0.056197
# residual sugar                    0.495482  0.552517 -0.267320  -0.185927
# chlorides                        -0.279630  0.362615  0.044708   0.395593
# free sulfur dioxide               0.720934  0.025717 -0.145854  -0.188457
# total sulfur dioxide              1.000000  0.032395 -0.238413  -0.275727
# density                           0.032395  1.000000  0.011686   0.259478
# pH                               -0.238413  0.011686  1.000000   0.192123
# sulphates                        -0.275727  0.259478  0.192123   1.000000
# alcohol                          -0.265740 -0.686745  0.121248  -0.003029
# quality                          -0.041385 -0.305858  0.019506   0.038485
# type                              0.700357 -0.390645 -0.329129  -0.487218
#
#                        alcohol   quality      type
# fixed acidity        -0.095452 -0.076743 -0.486740
# volatile acidity     -0.037640 -0.265699 -0.653036
# citric acid          -0.010493  0.085532  0.187397
# residual sugar       -0.359415 -0.036980  0.348821
# chlorides            -0.256916 -0.200666 -0.512678
# free sulfur dioxide  -0.179838  0.055463  0.471644
# total sulfur dioxide -0.265740 -0.041385  0.700357
# density              -0.686745 -0.305858 -0.390645
# pH                    0.121248  0.019506 -0.329129
# sulphates            -0.003029  0.038485 -0.487218
# alcohol               1.000000  0.444319  0.032970
# quality               0.444319  1.000000  0.119323
# type                  0.032970  0.119323  1.000000

# %%
sns.heatmap(wine.corr(), annot=True, cmap='coolwarm')

# %%
#너무 상관관계가 높은 아이들끼리는 같이 쓰지말고 둘중 하나를 쓰는게 좋음 공분산도가 높아짐

# %%
wine.corrwith(wine.quality).sort_values()
# Out:
# density                -0.305858
# volatile acidity       -0.265699
# chlorides              -0.200666
# fixed acidity          -0.076743
# total sulfur dioxide   -0.041385
# residual sugar         -0.036980
# pH                      0.019506
# sulphates               0.038485
# free sulfur dioxide     0.055463
# citric acid             0.085532
# type                    0.119323
# alcohol                 0.444319
# quality                 1.000000
# dtype: float64

# %% [markdown]
# ### 산점도 pairplot
# - 모든 회귀문제는 산점도가 있어야 파악이 용이
# - 하지만 모든 점을 산점도를 그리면   성능문제발생,   그래서 샘플링을 하여 산점도로 변수간 관계를 만듦

# %%
def sampling(data, n=300):         #와인 샘플링
    return data.loc[np.random.choice(data.index, size=n, replace=False)]        #choice  인덱스 골라냄,  replace 중복미허용F

# %%
red = wine[wine.type ==0]
white = wine[wine.type ==1]

# %%
red_sample = sampling(red)
print(red_sample.shape)
red_sample.head()
# Out:
# (300, 13)
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1073            8.0             0.620         0.33             2.7      0.088
# 622            10.0             0.580         0.22             1.9      0.080
# 1296            6.6             0.630         0.00             4.3      0.093
# 1586            7.5             0.310         0.41             2.4      0.065
# 1348            7.2             0.655         0.03             1.8      0.078
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1073                 16.0                  37.0  0.99720  3.31       0.58
# 622                   9.0                  32.0  0.99740  3.13       0.55
# 1296                 51.0                  77.5  0.99558  3.20       0.45
# 1586                 34.0                  60.0  0.99492  3.34       0.85
# 1348                  7.0                  12.0  0.99587  3.34       0.39
#
#       alcohol  quality  type
# 1073     10.7        6     0
# 622       9.5        5     0
# 1296      9.5        5     0
# 1586     11.4        6     0
# 1348      9.5        5     0

# %%
white_sample = sampling(white)
print(white_sample.shape)
white_sample.head()
# Out:
# (300, 13)
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 5899            6.4              0.29         0.30             6.5      0.209
# 6447            7.0              0.36         0.35             2.5      0.048
# 5162            7.0              0.48         0.12             4.5      0.050
# 2641            7.3              0.49         0.32             5.2      0.043
# 4940            7.6              0.17         0.27             4.6      0.050
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 5899                 62.0                 156.0  0.99478  3.10       0.40
# 6447                 67.0                 161.0  0.99146  3.05       0.56
# 5162                 23.0                  86.0  0.99398  2.86       0.35
# 2641                 18.0                 104.0  0.99520  3.24       0.45
# 4940                 23.0                  98.0  0.99422  3.08       0.47
#
#       alcohol  quality  type
# 5899      9.4        5     1
# 6447     11.1        6     1
# 5162      9.0        5     1
# 2641     10.7        4     1
# 4940      9.5        6     1

# %%
wine_sample = pd.concat([red_sample, white_sample])

# %%
sns.pairplot(wine_sample, hue='type', kind='reg',
            vars=['quality', 'alcohol', 'density', 'volatile acidity', 'residual sugar'])     #pairplot 회귀문제에서 꼭 필요***

# %% [markdown]
# ### .
# - 선형회귀모형  만들기

# %%
wine.columns = wine.columns.str.replace(' ','_')

# %%
wine.columns
# Out:
# Index(['fixed_acidity', 'volatile_acidity', 'citric_acid', 'residual_sugar',
#        'chlorides', 'free_sulfur_dioxide', 'total_sulfur_dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'type'],
#       dtype='object')

# %%
features = ['fixed_acidity', 'volatile_acidity', 'residual_sugar',
       'chlorides', 'free_sulfur_dioxide', 'density',
       'pH', 'sulphates', 'alcohol', 'type']                              #예측모델을 만들기 위해 핏쳐 셀렉션을 함

# %%
features_B = ['volatile_acidity', 'residual_sugar','density','alcohol', 'type']

# %%
features_C = ['volatile_acidity', 'residual_sugar','density','alcohol', 'type', 'density']

# %%
features_D = ['volatile_acidity', 'residual_sugar','density','alcohol', 'type', 'density','fixed_acidity']

# %%
features_E = ['volatile_acidity', 'residual_sugar','density','alcohol', 'type', 'density','fixed_acidity', 'chlorides']

# %%
features_F = ['volatile_acidity', 'residual_sugar','density','alcohol', 'type', 'density','fixed_acidity', 'chlorides', 'free_sulfur_dioxide']

# %%
features_G = ['volatile_acidity', 'residual_sugar','density','alcohol', 'type', 'density','fixed_acidity', 'chlorides', 'free_sulfur_dioxide', 'pH']

# %%
features_H = ['volatile_acidity', 'residual_sugar','density','alcohol', 'type', 'density','fixed_acidity', 'chlorides', 'free_sulfur_dioxide', 'pH', 'sulphates']

# %%
y = wine.quality
X = wine[wine.columns.difference(['quality', 'type'])]
X_standard = (X - X.mean())/ X.std()    #표준화 : 단위기준을 맞춤
wine_standard = pd.concat([X_standard, wine.quality, wine.type], axis=1)

# %%
X = wine_standard[features]
X_B = wine_standard[features_B]
X_C = wine_standard[features_C]
X_D = wine_standard[features_D]
X_E = wine_standard[features_E]
X_F = wine_standard[features_F]
X_G = wine_standard[features_G]
X_H = wine_standard[features_H]

# %% [markdown]
# # 훈련데이터셋과 테스트데이터셋으로 나누자
# ### 회귀분석의 경우는.... 훈련데이터셋과 테스트 데이터 셋을 나누어야 함

# %%
from sklearn.model_selection import train_test_split                   #머신러닝 라이브러리는 사이킷런에 있음

# %%
X_train, X_test, y_train, y_test = train_test_split(X, wine.quality, train_size=0.8, random_state=31)

X_B_train, X_B_test, y_B_train, y_B_test = train_test_split(X_B, wine.quality, train_size=0.8, random_state=31)
X_C_train, X_C_test, y_C_train, y_C_test = train_test_split(X_C, wine.quality, train_size=0.8, random_state=31)
X_D_train, X_D_test, y_D_train, y_D_test = train_test_split(X_D, wine.quality, train_size=0.8, random_state=31)
X_E_train, X_E_test, y_E_train, y_E_test = train_test_split(X_E, wine.quality, train_size=0.8, random_state=31)
X_F_train, X_F_test, y_F_train, y_F_test = train_test_split(X_F, wine.quality, train_size=0.8, random_state=31)
X_G_train, X_G_test, y_G_train, y_G_test = train_test_split(X_G, wine.quality, train_size=0.8, random_state=31)
X_H_train, X_H_test, y_H_train, y_H_test = train_test_split(X_H, wine.quality, train_size=0.8, random_state=31)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (5197, 10)
# (1300, 10)
# (5197,)
# (1300,)

# %%
print(X_B_train.shape)
print(X_B_test.shape)
print(y_B_train.shape)
print(y_B_test.shape)
# Out:
# (5197, 5)
# (1300, 5)
# (5197,)
# (1300,)

# %%
# 모델정의

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model_B = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model_B.fit(X_B_train, y_B_train)
# Out:
# LinearRegression()

# %%
prediction = model.predict(X_test)

# %%
prediction_B = model_B.predict(X_B_test)

# %%
prediction
# Out:
# array([5.60905571, 5.62501168, 6.17583394, ..., 5.29490736, 6.05439488,
#        5.41107896])

# %%
prediction_B
# Out:
# array([5.65532853, 5.58009165, 6.20560955, ..., 5.40446072, 5.88161446,
#        5.32981546])

# %% [markdown]
# ### 모델평가

# %%
from sklearn import metrics

# %%
metrics.mean_absolute_error(y_test, prediction)
# Out:
# 0.5526961889267856

# %%
metrics.mean_absolute_error(y_B_test, prediction_B)
# Out:
# 0.5623562106847024

# %%
metrics.mean_squared_error(y_test, prediction)                 #  오류율이 낮아야 좋은 모델
# Out:
# 0.4884991903691603

# %%
metrics.mean_squared_error(y_B_test, prediction_B)
# Out:
# 0.49952257208049156

# %% [markdown]
# ### 하단 개인작업구간

# %% [markdown]
# ### 숫자를 떨어뜨려라  (과제)
# - 1. 그전에 핏쳐의 셀렉션과 조합, 핏처 엔지니어링... 등
# - 2. 하이퍼 파라메터 수정해가며 수정
# - 3. 랜덤포레스트 이용.
#
# > **metrics.mean_squared_error(y_test, prediction)   오류율 낮추기

# %%
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestRegressor

# %%
test_model = RandomForestRegressor(n_estimators = 300, 
                                  max_depth = 10, 
                                  max_features =0.9,
                                  random_state=31)

# %%
cross_val_score(test_model, X_train, y_train, scoring= 'neg_mean_squared_error', cv=10)                 #'neg_mean_squared_error'
# Out:
# array([-0.44991263, -0.47870985, -0.42840055, -0.47093158, -0.40696158,
#        -0.33987749, -0.39503184, -0.48109935, -0.47319203, -0.44150803])

# %%
cross_val_score(test_model, X_train, y_train, scoring= 'neg_mean_squared_error', cv=10).mean()
# Out:
# -0.4365624925593471

# %%
hyper_result =[]

max_depth = [3,5,7,9,11,13]
max_feature = [0.7,0.8,0.9,1.0]


for a in max_depth:
    for b in max_feature:
        model = RandomForestRegressor(n_estimators = 300, 
                                          max_depth = a, 
                                          max_features =b,
                                          min_samples_split=2,
                                          min_samples_leaf=1,
                                          random_state=31)

        score = cross_val_score(model, X_train, y_train, scoring= 'neg_mean_squared_error', cv=10).mean()

        hyper_result.append({'점수' : score,
                             '피쳐모델' : "basic",
                             'MAX_depth': a,
                             'MAX_features': b})
              

        print("현재 스코어는 {0:.5f}".format(score))
# Out:
# 현재 스코어는 -0.55779
# 현재 스코어는 -0.55789
# 현재 스코어는 -0.55805
# 현재 스코어는 -0.55927
# 현재 스코어는 -0.51258
# 현재 스코어는 -0.51309
# 현재 스코어는 -0.51358
# 현재 스코어는 -0.51400
# 현재 스코어는 -0.47812
# 현재 스코어는 -0.47875
# 현재 스코어는 -0.47971
# 현재 스코어는 -0.48055
# 현재 스코어는 -0.44938
# 현재 스코어는 -0.44918
# 현재 스코어는 -0.45016
# 현재 스코어는 -0.45057
# 현재 스코어는 -0.42423
# 현재 스코어는 -0.42503
# 현재 스코어는 -0.42633
# 현재 스코어는 -0.42609
# 현재 스코어는 -0.40527
# 현재 스코어는 -0.40689
# 현재 스코어는 -0.40885
# 현재 스코어는 -0.40919

# %%
pd.DataFrame(hyper_result).sort_values(by='점수', ascending=False)
# Out:
#           점수   피쳐모델  MAX_depth  MAX_features
# 20 -0.405268  basic         13           0.7
# 21 -0.406890  basic         13           0.8
# 22 -0.408854  basic         13           0.9
# 23 -0.409187  basic         13           1.0
# 16 -0.424230  basic         11           0.7
# 17 -0.425031  basic         11           0.8
# 19 -0.426087  basic         11           1.0
# 18 -0.426328  basic         11           0.9
# 13 -0.449183  basic          9           0.8
# 12 -0.449380  basic          9           0.7
# 14 -0.450165  basic          9           0.9
# 15 -0.450575  basic          9           1.0
# 8  -0.478125  basic          7           0.7
# 9  -0.478747  basic          7           0.8
# 10 -0.479711  basic          7           0.9
# 11 -0.480553  basic          7           1.0
# 4  -0.512582  basic          5           0.7
# 5  -0.513090  basic          5           0.8
# 6  -0.513578  basic          5           0.9
# 7  -0.513996  basic          5           1.0
# 0  -0.557790  basic          3           0.7
# 1  -0.557888  basic          3           0.8
# 2  -0.558049  basic          3           0.9
# 3  -0.559272  basic          3           1.0

# %%
hyper_result_B =[]

max_depth = [3,5,7,9,11,13]
max_feature = [0.7,0.8,0.9,1.0]


for a in max_depth:
    for b in max_feature:
        model_B = RandomForestRegressor(n_estimators = 500, 
                                          max_depth = a, 
                                          max_features =b,
                                          min_samples_split=2,
                                          min_samples_leaf=1,
                                          random_state=31)

        score_B = cross_val_score(model_B, X_B_train, y_B_train, scoring= 'neg_mean_squared_error', cv=10).mean()

        hyper_result_B.append({'점수' : score_B,
                             '피쳐모델' : "B",
                             'MAX_depth': a,
                             'MAX_features': b})
              

        print("현재 스코어는 {0:.5f}".format(score_B))
# Out:
# 현재 스코어는 -0.57123
# 현재 스코어는 -0.56832
# 현재 스코어는 -0.56832
# 현재 스코어는 -0.56783
# 현재 스코어는 -0.53960
# 현재 스코어는 -0.53836
# 현재 스코어는 -0.53836
# 현재 스코어는 -0.53779
# 현재 스코어는 -0.51895
# 현재 스코어는 -0.51983
# 현재 스코어는 -0.51983
# 현재 스코어는 -0.52114
# 현재 스코어는 -0.50041
# 현재 스코어는 -0.50174
# 현재 스코어는 -0.50174
# 현재 스코어는 -0.50384
# 현재 스코어는 -0.48310
# 현재 스코어는 -0.48526
# 현재 스코어는 -0.48526
# 현재 스코어는 -0.48719
# 현재 스코어는 -0.46804
# 현재 스코어는 -0.47093
# 현재 스코어는 -0.47093
# 현재 스코어는 -0.47420

# %%
pd.DataFrame(hyper_result_B).sort_values(by='점수', ascending=False)
# Out:
#           점수 피쳐모델  MAX_depth  MAX_features
# 20 -0.468037    B         13           0.7
# 22 -0.470926    B         13           0.9
# 21 -0.470926    B         13           0.8
# 23 -0.474201    B         13           1.0
# 16 -0.483101    B         11           0.7
# 18 -0.485257    B         11           0.9
# 17 -0.485257    B         11           0.8
# 19 -0.487185    B         11           1.0
# 12 -0.500410    B          9           0.7
# 13 -0.501735    B          9           0.8
# 14 -0.501735    B          9           0.9
# 15 -0.503843    B          9           1.0
# 8  -0.518946    B          7           0.7
# 9  -0.519829    B          7           0.8
# 10 -0.519829    B          7           0.9
# 11 -0.521144    B          7           1.0
# 7  -0.537785    B          5           1.0
# 6  -0.538360    B          5           0.9
# 5  -0.538360    B          5           0.8
# 4  -0.539602    B          5           0.7
# 3  -0.567828    B          3           1.0
# 1  -0.568321    B          3           0.8
# 2  -0.568321    B          3           0.9
# 0  -0.571231    B          3           0.7

# %%
hyper_result_C =[]



max_depth = [3,5,7,9,11,13]
max_feature = [0.7,0.8,0.9,1.0]


for a in max_depth:
    for b in max_feature:

        model_C = RandomForestRegressor(n_estimators = 500, 
                                      max_depth = a, 
                                      max_features =b,
                                      min_samples_split=2,
                                      min_samples_leaf=1,
                                      random_state=31)

        
        score_C = cross_val_score(model_C, X_C_train, y_C_train, scoring= 'neg_mean_squared_error', cv=10).mean()


        hyper_result_C.append({'점수' : score_C,
                               '피쳐모델' : "C",
                               'MAX_depth': a,
                               'MAX_features': b})      
        

        print("현재 스코어는 {0:.5f}".format(score_C))
# Out:
# 현재 스코어는 -0.57110
# 현재 스코어는 -0.57110
# 현재 스코어는 -0.56829
# 현재 스코어는 -0.56783
# 현재 스코어는 -0.53954
# 현재 스코어는 -0.53954
# 현재 스코어는 -0.53872
# 현재 스코어는 -0.53779
# 현재 스코어는 -0.51938
# 현재 스코어는 -0.51938
# 현재 스코어는 -0.51982
# 현재 스코어는 -0.52136
# 현재 스코어는 -0.50085
# 현재 스코어는 -0.50085
# 현재 스코어는 -0.50143
# 현재 스코어는 -0.50405
# 현재 스코어는 -0.48313
# 현재 스코어는 -0.48313
# 현재 스코어는 -0.48437
# 현재 스코어는 -0.48723
# 현재 스코어는 -0.46916
# 현재 스코어는 -0.46916
# 현재 스코어는 -0.47141
# 현재 스코어는 -0.47402

# %%
pd.DataFrame(hyper_result_C).sort_values(by='점수', ascending=False)
# Out:
#           점수 피쳐모델  MAX_depth  MAX_features
# 21 -0.469163    C         13           0.8
# 20 -0.469163    C         13           0.7
# 22 -0.471413    C         13           0.9
# 23 -0.474021    C         13           1.0
# 17 -0.483126    C         11           0.8
# 16 -0.483126    C         11           0.7
# 18 -0.484368    C         11           0.9
# 19 -0.487234    C         11           1.0
# 13 -0.500849    C          9           0.8
# 12 -0.500849    C          9           0.7
# 14 -0.501433    C          9           0.9
# 15 -0.504053    C          9           1.0
# 9  -0.519375    C          7           0.8
# 8  -0.519375    C          7           0.7
# 10 -0.519816    C          7           0.9
# 11 -0.521357    C          7           1.0
# 7  -0.537791    C          5           1.0
# 6  -0.538725    C          5           0.9
# 5  -0.539544    C          5           0.8
# 4  -0.539544    C          5           0.7
# 3  -0.567829    C          3           1.0
# 2  -0.568293    C          3           0.9
# 1  -0.571098    C          3           0.8
# 0  -0.571098    C          3           0.7

# %%
hyper_result_D =[]



max_depth = [3,5,7,9,11,13]
max_feature = [0.7,0.8,0.9,1.0]


for a in max_depth:
    for b in max_feature:

        model_D = RandomForestRegressor(n_estimators = 500, 
                                      max_depth = a, 
                                      max_features =b,
                                      min_samples_split=2,
                                      min_samples_leaf=1,
                                      random_state=31)

        
        score_D = cross_val_score(model_D, X_D_train, y_D_train, scoring= 'neg_mean_squared_error', cv=10).mean()


        hyper_result_D.append({'점수' : score_D,
                               '피쳐모델' : "D",
                               'MAX_depth': a,
                               'MAX_features': b})      
        

        print("현재 스코어는 {0:.5f}".format(score_D))
# Out:
# 현재 스코어는 -0.57349
# 현재 스코어는 -0.56932
# 현재 스코어는 -0.56787
# 현재 스코어는 -0.56807
# 현재 스코어는 -0.53935
# 현재 스코어는 -0.53777
# 현재 스코어는 -0.53719
# 현재 스코어는 -0.53727
# 현재 스코어는 -0.51574
# 현재 스코어는 -0.51573
# 현재 스코어는 -0.51671
# 현재 스코어는 -0.51707
# 현재 스코어는 -0.49306
# 현재 스코어는 -0.49371
# 현재 스코어는 -0.49497
# 현재 스코어는 -0.49630
# 현재 스코어는 -0.47254
# 현재 스코어는 -0.47177
# 현재 스코어는 -0.47468
# 현재 스코어는 -0.47576
# 현재 스코어는 -0.45547
# 현재 스코어는 -0.45553
# 현재 스코어는 -0.45733
# 현재 스코어는 -0.45881

# %%
pd.DataFrame(hyper_result_D).sort_values(by='점수', ascending=False)
# Out:
#           점수 피쳐모델  MAX_depth  MAX_features
# 20 -0.455471    D         13           0.7
# 21 -0.455531    D         13           0.8
# 22 -0.457331    D         13           0.9
# 23 -0.458812    D         13           1.0
# 17 -0.471774    D         11           0.8
# 16 -0.472536    D         11           0.7
# 18 -0.474679    D         11           0.9
# 19 -0.475756    D         11           1.0
# 12 -0.493060    D          9           0.7
# 13 -0.493714    D          9           0.8
# 14 -0.494967    D          9           0.9
# 15 -0.496298    D          9           1.0
# 9  -0.515732    D          7           0.8
# 8  -0.515742    D          7           0.7
# 10 -0.516713    D          7           0.9
# 11 -0.517074    D          7           1.0
# 6  -0.537194    D          5           0.9
# 7  -0.537272    D          5           1.0
# 5  -0.537766    D          5           0.8
# 4  -0.539351    D          5           0.7
# 2  -0.567867    D          3           0.9
# 3  -0.568068    D          3           1.0
# 1  -0.569317    D          3           0.8
# 0  -0.573489    D          3           0.7

# %%
hyper_result_E =[]



max_depth = [3,5,7,9,11,13]
max_feature = [0.7,0.8,0.9,1.0]


for a in max_depth:
    for b in max_feature:

        model_E = RandomForestRegressor(n_estimators = 500, 
                                      max_depth = a, 
                                      max_features =b,
                                      min_samples_split=2,
                                      min_samples_leaf=1,
                                      random_state=31)

        
        score_E = cross_val_score(model_E, X_E_train, y_E_train, scoring= 'neg_mean_squared_error', cv=10).mean()


        hyper_result_E.append({'점수' : score_E,
                               '피쳐모델' : "E",
                               'MAX_depth': a,
                               'MAX_features': b})      
        

        print("현재 스코어는 {0:.5f}".format(score_E))
# Out:
# 현재 스코어는 -0.57234
# 현재 스코어는 -0.56969
# 현재 스코어는 -0.56819
# 현재 스코어는 -0.56844
# 현재 스코어는 -0.53891
# 현재 스코어는 -0.53762
# 현재 스코어는 -0.53738
# 현재 스코어는 -0.53710
# 현재 스코어는 -0.51393
# 현재 스코어는 -0.51426
# 현재 스코어는 -0.51429
# 현재 스코어는 -0.51543
# 현재 스코어는 -0.48953
# 현재 스코어는 -0.49098
# 현재 스코어는 -0.49149
# 현재 스코어는 -0.49295
# 현재 스코어는 -0.46805
# 현재 스코어는 -0.46885
# 현재 스코어는 -0.46988
# 현재 스코어는 -0.47200
# 현재 스코어는 -0.45065
# 현재 스코어는 -0.45191
# 현재 스코어는 -0.45299
# 현재 스코어는 -0.45547

# %%
pd.DataFrame(hyper_result_E).sort_values(by='점수', ascending=False)
# Out:
#           점수 피쳐모델  MAX_depth  MAX_features
# 20 -0.450648    E         13           0.7
# 21 -0.451912    E         13           0.8
# 22 -0.452989    E         13           0.9
# 23 -0.455471    E         13           1.0
# 16 -0.468048    E         11           0.7
# 17 -0.468847    E         11           0.8
# 18 -0.469883    E         11           0.9
# 19 -0.472000    E         11           1.0
# 12 -0.489533    E          9           0.7
# 13 -0.490981    E          9           0.8
# 14 -0.491490    E          9           0.9
# 15 -0.492947    E          9           1.0
# 8  -0.513932    E          7           0.7
# 9  -0.514264    E          7           0.8
# 10 -0.514287    E          7           0.9
# 11 -0.515429    E          7           1.0
# 7  -0.537095    E          5           1.0
# 6  -0.537380    E          5           0.9
# 5  -0.537617    E          5           0.8
# 4  -0.538906    E          5           0.7
# 2  -0.568192    E          3           0.9
# 3  -0.568436    E          3           1.0
# 1  -0.569691    E          3           0.8
# 0  -0.572338    E          3           0.7

# %%
hyper_result_F =[]



max_depth = [3,5,7,9,11,13]
max_feature = [0.7,0.8,0.9,1.0]


for a in max_depth:
    for b in max_feature:

        model_F = RandomForestRegressor(n_estimators = 500, 
                                      max_depth = a, 
                                      max_features =b,
                                      min_samples_split=2,
                                      min_samples_leaf=1,
                                      random_state=31)

        
        score_F = cross_val_score(model_F, X_F_train, y_F_train, scoring= 'neg_mean_squared_error', cv=10).mean()


        hyper_result_F.append({'점수' : score_F,
                               '피쳐모델' : "F",
                               'MAX_depth': a,
                               'MAX_features': b})      
        

        print("현재 스코어는 {0:.5f}".format(score_F))
# Out:
# 현재 스코어는 -0.56221
# 현재 스코어는 -0.56062
# 현재 스코어는 -0.56118
# 현재 스코어는 -0.56271
# 현재 스코어는 -0.52237
# 현재 스코어는 -0.52312
# 현재 스코어는 -0.52317
# 현재 스코어는 -0.52393
# 현재 스코어는 -0.49180
# 현재 스코어는 -0.49254
# 현재 스코어는 -0.49297
# 현재 스코어는 -0.49406
# 현재 스코어는 -0.46505
# 현재 스코어는 -0.46546
# 현재 스코어는 -0.46642
# 현재 스코어는 -0.46748
# 현재 스코어는 -0.44137
# 현재 스코어는 -0.44102
# 현재 스코어는 -0.44314
# 현재 스코어는 -0.44532
# 현재 스코어는 -0.42286
# 현재 스코어는 -0.42432
# 현재 스코어는 -0.42548
# 현재 스코어는 -0.42730

# %%
pd.DataFrame(hyper_result_F).sort_values(by='점수', ascending=False)
# Out:
#           점수 피쳐모델  MAX_depth  MAX_features
# 20 -0.422864    F         13           0.7
# 21 -0.424324    F         13           0.8
# 22 -0.425477    F         13           0.9
# 23 -0.427303    F         13           1.0
# 17 -0.441018    F         11           0.8
# 16 -0.441367    F         11           0.7
# 18 -0.443138    F         11           0.9
# 19 -0.445324    F         11           1.0
# 12 -0.465052    F          9           0.7
# 13 -0.465461    F          9           0.8
# 14 -0.466423    F          9           0.9
# 15 -0.467476    F          9           1.0
# 8  -0.491804    F          7           0.7
# 9  -0.492535    F          7           0.8
# 10 -0.492971    F          7           0.9
# 11 -0.494060    F          7           1.0
# 4  -0.522372    F          5           0.7
# 5  -0.523118    F          5           0.8
# 6  -0.523172    F          5           0.9
# 7  -0.523932    F          5           1.0
# 1  -0.560622    F          3           0.8
# 2  -0.561177    F          3           0.9
# 0  -0.562214    F          3           0.7
# 3  -0.562712    F          3           1.0

# %%
hyper_result_G =[]



max_depth = [3,5,7,9,11,13]
max_feature = [0.7,0.8,0.9,1.0]


for a in max_depth:
    for b in max_feature:

        model_G = RandomForestRegressor(n_estimators = 500, 
                                      max_depth = a, 
                                      max_features =b,
                                      min_samples_split=2,
                                      min_samples_leaf=1,
                                      random_state=31)

        
        score_G = cross_val_score(model_G, X_G_train, y_G_train, scoring= 'neg_mean_squared_error', cv=10).mean()


        hyper_result_G.append({'점수' : score_G,
                               '피쳐모델' : "G",
                               'MAX_depth': a,
                               'MAX_features': b})      
        

        print("현재 스코어는 {0:.5f}".format(score_G))
# Out:
# 현재 스코어는 -0.56103
# 현재 스코어는 -0.56104
# 현재 스코어는 -0.56143
# 현재 스코어는 -0.56274
# 현재 스코어는 -0.52163
# 현재 스코어는 -0.52224
# 현재 스코어는 -0.52285
# 현재 스코어는 -0.52366
# 현재 스코어는 -0.48924
# 현재 스코어는 -0.49021
# 현재 스코어는 -0.49114
# 현재 스코어는 -0.49206
# 현재 스코어는 -0.46077
# 현재 스코어는 -0.46202
# 현재 스코어는 -0.46258
# 현재 스코어는 -0.46437
# 현재 스코어는 -0.43599
# 현재 스코어는 -0.43656
# 현재 스코어는 -0.43880
# 현재 스코어는 -0.44058
# 현재 스코어는 -0.41868
# 현재 스코어는 -0.41928
# 현재 스코어는 -0.42097
# 현재 스코어는 -0.42257

# %%
pd.DataFrame(hyper_result_G).sort_values(by='점수', ascending=False)
# Out:
#           점수 피쳐모델  MAX_depth  MAX_features
# 20 -0.418678    G         13           0.7
# 21 -0.419284    G         13           0.8
# 22 -0.420970    G         13           0.9
# 23 -0.422566    G         13           1.0
# 16 -0.435988    G         11           0.7
# 17 -0.436563    G         11           0.8
# 18 -0.438796    G         11           0.9
# 19 -0.440581    G         11           1.0
# 12 -0.460769    G          9           0.7
# 13 -0.462018    G          9           0.8
# 14 -0.462580    G          9           0.9
# 15 -0.464368    G          9           1.0
# 8  -0.489239    G          7           0.7
# 9  -0.490210    G          7           0.8
# 10 -0.491141    G          7           0.9
# 11 -0.492056    G          7           1.0
# 4  -0.521634    G          5           0.7
# 5  -0.522241    G          5           0.8
# 6  -0.522854    G          5           0.9
# 7  -0.523658    G          5           1.0
# 0  -0.561031    G          3           0.7
# 1  -0.561041    G          3           0.8
# 2  -0.561429    G          3           0.9
# 3  -0.562741    G          3           1.0

# %%
hyper_result_H =[]



max_depth = [3,5,7,9,11,13]
max_feature = [0.7,0.8,0.9,1.0]


for a in max_depth:
    for b in max_feature:

        model_H = RandomForestRegressor(n_estimators = 500, 
                                      max_depth = a, 
                                      max_features =b,
                                      min_samples_split=2,
                                      min_samples_leaf=1,
                                      random_state=31)

        
        score_H = cross_val_score(model_H, X_H_train, y_H_train, scoring= 'neg_mean_squared_error', cv=10).mean()


        hyper_result_H.append({'점수' : score_H,
                               '피쳐모델' : "H",
                               'MAX_depth': a,
                               'MAX_features': b})      
        

        print("현재 스코어는 {0:.5f}".format(score_H))
# Out:
# 현재 스코어는 -0.55980
# 현재 스코어는 -0.55833
# 현재 스코어는 -0.55769
# 현재 스코어는 -0.55914
# 현재 스코어는 -0.51335
# 현재 스코어는 -0.51266
# 현재 스코어는 -0.51289
# 현재 스코어는 -0.51377
# 현재 스코어는 -0.47824
# 현재 스코어는 -0.47901
# 현재 스코어는 -0.47942
# 현재 스코어는 -0.48024
# 현재 스코어는 -0.44857
# 현재 스코어는 -0.44867
# 현재 스코어는 -0.44956
# 현재 스코어는 -0.45049
# 현재 스코어는 -0.42286
# 현재 스코어는 -0.42384
# 현재 스코어는 -0.42379
# 현재 스코어는 -0.42599
# 현재 스코어는 -0.40378
# 현재 스코어는 -0.40586
# 현재 스코어는 -0.40715
# 현재 스코어는 -0.40904

# %%
pd.DataFrame(hyper_result_H).sort_values(by='점수', ascending=False)
# Out:
#           점수 피쳐모델  MAX_depth  MAX_features
# 20 -0.403781    H         13           0.7
# 21 -0.405858    H         13           0.8
# 22 -0.407150    H         13           0.9
# 23 -0.409038    H         13           1.0
# 16 -0.422862    H         11           0.7
# 18 -0.423790    H         11           0.9
# 17 -0.423836    H         11           0.8
# 19 -0.425994    H         11           1.0
# 12 -0.448565    H          9           0.7
# 13 -0.448673    H          9           0.8
# 14 -0.449559    H          9           0.9
# 15 -0.450495    H          9           1.0
# 8  -0.478244    H          7           0.7
# 9  -0.479005    H          7           0.8
# 10 -0.479415    H          7           0.9
# 11 -0.480240    H          7           1.0
# 5  -0.512664    H          5           0.8
# 6  -0.512889    H          5           0.9
# 4  -0.513349    H          5           0.7
# 7  -0.513768    H          5           1.0
# 2  -0.557686    H          3           0.9
# 1  -0.558333    H          3           0.8
# 3  -0.559144    H          3           1.0
# 0  -0.559797    H          3           0.7

# %%
print("최소에러율")
print(pd.DataFrame(hyper_result)['점수'].max())
print(pd.DataFrame(hyper_result_B)['점수'].max())
print(pd.DataFrame(hyper_result_C)['점수'].max())
print(pd.DataFrame(hyper_result_D)['점수'].max())
print(pd.DataFrame(hyper_result_E)['점수'].max())
print(pd.DataFrame(hyper_result_F)['점수'].max())
print(pd.DataFrame(hyper_result_G)['점수'].max())
print(pd.DataFrame(hyper_result_H)['점수'].max())

print(" ")
print("평균에러율")
print(pd.DataFrame(hyper_result)['점수'].mean())
print(pd.DataFrame(hyper_result_B)['점수'].mean())
print(pd.DataFrame(hyper_result_C)['점수'].mean())
print(pd.DataFrame(hyper_result_D)['점수'].mean())
print(pd.DataFrame(hyper_result_E)['점수'].mean())
print(pd.DataFrame(hyper_result_F)['점수'].mean())
print(pd.DataFrame(hyper_result_G)['점수'].mean())
print(pd.DataFrame(hyper_result_H)['점수'].mean())
# Out:
# 최소에러율
# -0.40526813458040706
# -0.468037070468265
# -0.4691626787437042
# -0.4554709101885523
# -0.4506482022450161
# -0.4228637285534889
# -0.418677562951664
# -0.4037809933346651
#
# 평균에러율
# -0.47227329668630863
# -0.5142570582703881
# -0.514276755773538
# -0.5081463938160321
# -0.5059298190813477
# -0.4852465468273172
# -0.4826014311255513
# -0.47183901628261915

# %%
# 최종 모델정의

# %%
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestRegressor

# %%
Finalmodel = RandomForestRegressor()
Finalmodel_B = RandomForestRegressor()
Finalmodel_C = RandomForestRegressor()
Finalmodel_D = RandomForestRegressor()
Finalmodel_E = RandomForestRegressor()
Finalmodel_F = RandomForestRegressor()
Finalmodel_G = RandomForestRegressor()
Finalmodel_H = RandomForestRegressor()

# %%
Finalmodel.fit(X_train, y_train)
Finalmodel_B.fit(X_B_train, y_B_train)
Finalmodel_C.fit(X_C_train, y_C_train)
Finalmodel_D.fit(X_D_train, y_D_train)
Finalmodel_E.fit(X_E_train, y_E_train)
Finalmodel_F.fit(X_F_train, y_F_train)
Finalmodel_G.fit(X_G_train, y_G_train)
Finalmodel_H.fit(X_H_train, y_H_train)
# Out:
# RandomForestRegressor()

# %%
prediction = Finalmodel.predict(X_test)

# %%
prediction_B = Finalmodel_B.predict(X_B_test)
prediction_C = Finalmodel_C.predict(X_C_test)
prediction_D = Finalmodel_D.predict(X_D_test)
prediction_E = Finalmodel_E.predict(X_E_test)
prediction_F = Finalmodel_F.predict(X_F_test)
prediction_G = Finalmodel_G.predict(X_G_test)
prediction_H = Finalmodel_H.predict(X_H_test)

# %%
prediction
# Out:
# array([5.99, 5.52, 6.92, ..., 5.73, 6.46, 5.57])

# %%
prediction_B
# Out:
# array([6.01, 5.41, 7.01, ..., 5.44, 6.88, 5.07])

# %%
prediction_C
# Out:
# array([5.98, 5.36, 6.97, ..., 5.42, 6.85, 5.34])

# %%
prediction_D
# Out:
# array([5.98      , 5.38      , 7.03      , ..., 5.8       , 6.84      ,
#        5.18666667])

# %%
prediction_E
# Out:
# array([6.  , 5.14, 6.97, ..., 5.78, 6.65, 5.27])

# %%
prediction_F
# Out:
# array([5.96, 5.2 , 6.92, ..., 5.77, 6.49, 5.34])

# %%
prediction_G
# Out:
# array([5.97, 5.54, 6.85, ..., 5.76, 6.64, 5.4 ])

# %%
prediction_H
# Out:
# array([5.96, 5.6 , 6.81, ..., 5.75, 6.43, 5.42])

# %% [markdown]
# ### 모델평가

# %%
from sklearn import metrics

# %%
metrics.mean_squared_error(y_test, prediction)                 #  오류율이 낮아야 좋은 모델
# Out:
# 0.3485079230769231

# %%
metrics.mean_squared_error(y_B_test, prediction_B)
# Out:
# 0.4045097200427351

# %%
metrics.mean_squared_error(y_B_test, prediction_B)
# Out:
# 0.4045097200427351

# %%
metrics.mean_squared_error(y_C_test, prediction_C)
# Out:
# 0.39937553583333335

# %%
metrics.mean_squared_error(y_D_test, prediction_D)
# Out:
# 0.399342504017094

# %%
metrics.mean_squared_error(y_E_test, prediction_E)
# Out:
# 0.38361507692307695

# %%
metrics.mean_squared_error(y_F_test, prediction_F)
# Out:
# 0.3587277692307692

# %%
metrics.mean_squared_error(y_G_test, prediction_G)
# Out:
# 0.3603193076923077

# %%
metrics.mean_squared_error(y_H_test, prediction_H)          # 가장 낮은 오류율로 H모델 사용이 현재로써는 가장 유효함
# Out:
# 0.3556487692307692

# %% [markdown]
# ### 상단 개인작업구간

# %%
formula = 'quality ~ alcohol + density + residual_sugar + type + volatile_acidity + chlorides'   #이꼴 표시이나 물결로 함

# %%
formula_all = 'quality ~ fixed_acidity + volatile_acidity + residual_sugar + chlorides + free_sulfur_dioxide + total_sulfur_dioxide + density + pH + sulphates + alcohol + type'

#코드를 거쳐 한 번 전체 확인 후(pvalue등...)  불필요한 증명력을 가진사항은 지워 봄

# %%
from statsmodels.formula.api import ols       #statsmodel:   모든 통계 공식이 들어있음.   ols:최소제곱법

# %%
formula_model = ols(formula, data=wine).fit()          #

# %%
formula_model.summary()                                #R-squared는  설명력을 갖추었 다는 것
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                quality   R-squared:                       0.279
# Model:                            OLS   Adj. R-squared:                  0.278
# Method:                 Least Squares   F-statistic:                     418.9
# Date:                Sun, 29 May 2022   Prob (F-statistic):               0.00
# Time:                        05:25:41   Log-Likelihood:                -7274.5
# No. Observations:                6497   AIC:                         1.456e+04
# Df Residuals:                    6490   BIC:                         1.461e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept           36.3297      8.509      4.270      0.000      19.649      53.010
# alcohol              0.3114      0.013     24.164      0.000       0.286       0.337
# density            -33.1933      8.446     -3.930      0.000     -49.750     -16.637
# residual_sugar       0.0353      0.004      9.082      0.000       0.028       0.043
# type                -0.4592      0.047     -9.847      0.000      -0.551      -0.368
# volatile_acidity    -1.7047      0.074    -23.005      0.000      -1.850      -1.559
# chlorides           -0.5035      0.321     -1.569      0.117      -1.133       0.126
# ==============================================================================
# Omnibus:                      113.796   Durbin-Watson:                   1.654
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              229.104
# Skew:                           0.032   Prob(JB):                     1.78e-50
# Kurtosis:                       3.918   Cond. No.                     1.58e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.58e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
#density  -33에 대한 확인
wine.head()
#0.9978    이렇게 단위차이의 격차가 너무 차이남. 그래서 단위기준을 맞추어 주어야 함. 표준화
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  type
# 0      9.4        5     0
# 1      9.8        5     0
# 2      9.8        5     0
# 3      9.8        6     0
# 4      9.4        5     0

# %% [markdown]
# ### ** 독립변수의 표준화
# - 종속변수는 절대로 표준화를 하면 안됨

# %%
formula_model = ols(formula, data=wine_standard).fit()

# %%
formula_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                quality   R-squared:                       0.279
# Model:                            OLS   Adj. R-squared:                  0.278
# Method:                 Least Squares   F-statistic:                     418.9
# Date:                Sun, 29 May 2022   Prob (F-statistic):               0.00
# Time:                        05:25:41   Log-Likelihood:                -7274.5
# No. Observations:                6497   AIC:                         1.456e+04
# Df Residuals:                    6490   BIC:                         1.461e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept            6.1646      0.036    169.618      0.000       6.093       6.236
# alcohol              0.3714      0.015     24.164      0.000       0.341       0.402
# density             -0.0995      0.025     -3.930      0.000      -0.149      -0.050
# residual_sugar       0.1679      0.018      9.082      0.000       0.132       0.204
# type                -0.4592      0.047     -9.847      0.000      -0.551      -0.368
# volatile_acidity    -0.2807      0.012    -23.005      0.000      -0.305      -0.257
# chlorides           -0.0176      0.011     -1.569      0.117      -0.040       0.004
# ==============================================================================
# Omnibus:                      113.796   Durbin-Watson:                   1.654
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              229.104
# Skew:                           0.032   Prob(JB):                     1.78e-50
# Kurtosis:                       3.918   Cond. No.                         10.4
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
formula_all_model = ols(formula_all, data=wine_standard).fit()

# %%
formula_all_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                quality   R-squared:                       0.296
# Model:                            OLS   Adj. R-squared:                  0.295
# Method:                 Least Squares   F-statistic:                     248.4
# Date:                Sun, 29 May 2022   Prob (F-statistic):               0.00
# Time:                        05:25:41   Log-Likelihood:                -7195.5
# No. Observations:                6497   AIC:                         1.442e+04
# Df Residuals:                    6485   BIC:                         1.450e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept                6.0939      0.044    139.896      0.000       6.009       6.179
# fixed_acidity            0.1069      0.020      5.351      0.000       0.068       0.146
# volatile_acidity        -0.2422      0.013    -19.180      0.000      -0.267      -0.217
# residual_sugar           0.2977      0.028     10.548      0.000       0.242       0.353
# chlorides               -0.0281      0.012     -2.428      0.015      -0.051      -0.005
# free_sulfur_dioxide      0.0877      0.014      6.449      0.000       0.061       0.114
# total_sulfur_dioxide    -0.0806      0.018     -4.428      0.000      -0.116      -0.045
# density                 -0.3136      0.043     -7.307      0.000      -0.398      -0.229
# pH                       0.0811      0.015      5.587      0.000       0.053       0.110
# sulphates                0.1069      0.011      9.439      0.000       0.085       0.129
# alcohol                  0.2635      0.021     12.315      0.000       0.222       0.305
# type                    -0.3655      0.057     -6.468      0.000      -0.476      -0.255
# ==============================================================================
# Omnibus:                      140.952   Durbin-Watson:                   1.647
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              313.758
# Skew:                           0.017   Prob(JB):                     7.38e-69
# Kurtosis:                       4.076   Cond. No.                         15.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
